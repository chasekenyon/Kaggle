# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
def load_data():
    train = pd.read_csv("/kaggle/input/titanic/train.csv")
    train.name = 'train'
    test = pd.read_csv("/kaggle/input/titanic/test.csv")
    test.name = 'test'
    return train, test

# %%
train_data, test_data = load_data()
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def clean_data(df):
    name = df.name
    df['Sex'] = df['Sex'].replace({"male": 0, "female": 1})
    df = pd.get_dummies(df, columns=['Embarked'])
    df = df.drop(["PassengerId", "Name", "Ticket", "Cabin"], axis = 1)
    if name != 'test':
        X_train = df.drop('Survived', axis = 1)
        X_train['Age'] = X_train['Age'].fillna(X_train['Age'].mean())
        y_train = df['Survived']
        return X_train, y_train
    df['Age'] = df['Age'].fillna(df['Age'].mean())
    df['Fare'] = df['Fare'].fillna(df['Fare'].mean())
    return df

# %%
X_train, y_train = clean_data(train_data)
X_test = clean_data(test_data)

# %%
X_train.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0       3    0  22.0      1      0   7.2500       False       False
# 1       1    1  38.0      1      0  71.2833        True       False
# 2       3    1  26.0      0      0   7.9250       False       False
# 3       1    1  35.0      1      0  53.1000       False       False
# 4       3    0  35.0      0      0   8.0500       False       False
#
#    Embarked_S
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True

# %%
from numpy import mean, std
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score

X_train = np.asarray(X_train).astype('float32')
X_test = np.asarray(X_test).astype('float32')
y_train = np.asarray(y_train).astype('float32')

input_shape = X_train.shape

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(9,)),
    Dense(128, activation = 'relu'),
    Dropout(0.2),
    Dense(64, activation = 'relu'),
    Dropout(0.2),
    Dense(1, activation = 'sigmoid')
])

model.compile(optimizer = tf.keras.optimizers.AdamW(),
             loss = tf.keras.losses.BinaryCrossentropy(),
             metrics = ["accuracy"])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               1280
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 9,601
# Trainable params: 9,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 1s 2ms/step - loss: 1.9527 - accuracy: 0.5443
# Epoch 2/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.1812 - accuracy: 0.6308
# Epoch 3/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.0153 - accuracy: 0.6117
# Epoch 4/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.9812 - accuracy: 0.6016
# Epoch 5/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.8409 - accuracy: 0.6431
# Epoch 6/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7636 - accuracy: 0.6442
# Epoch 7/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7460 - accuracy: 0.6667
# Epoch 8/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.6599
# Epoch 9/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6402 - accuracy: 0.6936
# Epoch 10/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6611 - accuracy: 0.6655
# Epoch 11/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6977 - accuracy: 0.6678
# Epoch 12/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.6846
# Epoch 13/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6112 - accuracy: 0.6857
# Epoch 14/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6125 - accuracy: 0.6689
# Epoch 15/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6099 - accuracy: 0.6958
# Epoch 16/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6007 - accuracy: 0.6891
# Epoch 17/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.7071
# Epoch 18/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5880 - accuracy: 0.6970
# Epoch 19/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5922 - accuracy: 0.7015
# Epoch 20/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5727 - accuracy: 0.6992
# Epoch 21/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5701 - accuracy: 0.7127
# Epoch 22/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5596 - accuracy: 0.7160
# Epoch 23/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5456 - accuracy: 0.7363
# Epoch 24/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5597 - accuracy: 0.7217
# Epoch 25/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5502 - accuracy: 0.7351
# Epoch 26/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5487 - accuracy: 0.7329
# Epoch 27/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5234 - accuracy: 0.7486
# Epoch 28/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5392 - accuracy: 0.7475
# Epoch 29/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.7576
# Epoch 30/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5306 - accuracy: 0.7497
# Epoch 31/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5230 - accuracy: 0.7710
# Epoch 32/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5201 - accuracy: 0.7654
# Epoch 33/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.7677
# Epoch 34/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5315 - accuracy: 0.7632
# Epoch 35/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5098 - accuracy: 0.7789
# Epoch 36/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.7677
# Epoch 37/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7834
# Epoch 38/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5013 - accuracy: 0.7609
# Epoch 39/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.7576
# Epoch 40/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5117 - accuracy: 0.7778
# Epoch 41/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5104 - accuracy: 0.7576
# Epoch 42/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4884 - accuracy: 0.7890
# Epoch 43/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.7722
# Epoch 44/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4934 - accuracy: 0.7935
# Epoch 45/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4828 - accuracy: 0.7811
# Epoch 46/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4850 - accuracy: 0.7879
# Epoch 47/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4790 - accuracy: 0.7856
# Epoch 48/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 0.7924
# Epoch 49/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4831 - accuracy: 0.7879
# Epoch 50/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4728 - accuracy: 0.8025
# Epoch 51/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4669 - accuracy: 0.8013
# Epoch 52/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.7778
# Epoch 53/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.8013
# Epoch 54/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.7969
# Epoch 55/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4730 - accuracy: 0.7879
# Epoch 56/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.7879
# Epoch 57/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7946
# Epoch 58/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4565 - accuracy: 0.7980
# Epoch 59/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.7856
# Epoch 60/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4590 - accuracy: 0.7912
# Epoch 61/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.7868
# Epoch 62/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.8025
# Epoch 63/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.8013
# Epoch 64/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.8171
# Epoch 65/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4595 - accuracy: 0.8081
# Epoch 66/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.7879
# Epoch 67/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4606 - accuracy: 0.7935
# Epoch 68/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4283 - accuracy: 0.8171
# Epoch 69/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.8036
# Epoch 70/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4697 - accuracy: 0.7901
# Epoch 71/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4470 - accuracy: 0.7890
# Epoch 72/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4420 - accuracy: 0.8058
# Epoch 73/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4569 - accuracy: 0.8013
# Epoch 74/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4338 - accuracy: 0.8137
# Epoch 75/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.8092
# Epoch 76/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.8036
# Epoch 77/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4193 - accuracy: 0.8171
# Epoch 78/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.8137
# Epoch 79/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.8036
# Epoch 80/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4296 - accuracy: 0.8047
# Epoch 81/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.8114
# Epoch 82/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4348 - accuracy: 0.8081
# Epoch 83/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4416 - accuracy: 0.8058
# Epoch 84/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.7991
# Epoch 85/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.8070
# Epoch 86/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4214 - accuracy: 0.8103
# Epoch 87/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.8002
# Epoch 88/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8137
# Epoch 89/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.8227
# Epoch 90/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8114
# Epoch 91/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4147 - accuracy: 0.8171
# Epoch 92/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.8025
# Epoch 93/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4266 - accuracy: 0.8148
# Epoch 94/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4235 - accuracy: 0.8171
# Epoch 95/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.8193
# Epoch 96/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4255 - accuracy: 0.8171
# Epoch 97/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4147 - accuracy: 0.8137
# Epoch 98/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4206 - accuracy: 0.8103
# Epoch 99/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8238
# Epoch 100/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4223 - accuracy: 0.8114

# %%
acc = history.history['accuracy']
train_loss = history.history['loss']

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, label='Training acc')
plt.title('Training accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, train_loss, label='Training loss')
plt.title('Training loss')
plt.legend()

plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 14/14 [==============================] - 0s 1ms/step

# %%
output = np.c_[test_data["PassengerId"].to_numpy(), y_pred].astype(int)
output = pd.DataFrame(output, columns = ['PassengerId', 'Survived'])
output.to_csv("Dropout_submission.csv", index = False)
