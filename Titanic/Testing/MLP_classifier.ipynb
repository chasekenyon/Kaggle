# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
def load_data():
    train = pd.read_csv("/kaggle/input/titanic/train.csv")
    train.name = 'train'
    test = pd.read_csv("/kaggle/input/titanic/test.csv")
    test.name = 'test'
    return train, test

# %%
train_data, test_data = load_data()
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def clean_data(df):
    name = df.name
    df['Sex'] = df['Sex'].replace({"male": 0, "female": 1})
    df = pd.get_dummies(df, columns=['Embarked'])
    df = df.drop(["PassengerId", "Name", "Ticket", "Cabin"], axis = 1)
    if name != 'test':
        X_train = df.drop('Survived', axis = 1)
        X_train['Age'] = X_train['Age'].fillna(X_train['Age'].mean())
        y_train = df['Survived']
        return X_train, y_train
    df['Age'] = df['Age'].fillna(df['Age'].mean())
    df['Fare'] = df['Fare'].fillna(df['Fare'].mean())
    return df

# %%
X_train, y_train = clean_data(train_data)
X_test = clean_data(test_data)

# %%
X_train.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0       3    0  22.0      1      0   7.2500       False       False
# 1       1    1  38.0      1      0  71.2833        True       False
# 2       3    1  26.0      0      0   7.9250       False       False
# 3       1    1  35.0      1      0  53.1000       False       False
# 4       3    0  35.0      0      0   8.0500       False       False
#
#    Embarked_S
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True

# %%
from numpy import mean, std
import tensorflow as tf
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score

X_train = np.asarray(X_train).astype('float32')
X_test = np.asarray(X_test).astype('float32')
y_train = np.asarray(y_train).astype('float32')

model = tf.keras.Sequential([
    Dense(100, activation = 'relu'),
    Dense(10, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
model.compile(optimizer = tf.keras.optimizers.AdamW(),
             loss = tf.keras.losses.BinaryCrossentropy(),
             metrics = ["accuracy"])

history = model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 1s 2ms/step - loss: 1.0035 - accuracy: 0.6779
# Epoch 2/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6184 - accuracy: 0.6880
# Epoch 3/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5865 - accuracy: 0.6846
# Epoch 4/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5693 - accuracy: 0.7003
# Epoch 5/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5509 - accuracy: 0.7048
# Epoch 6/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5295 - accuracy: 0.7329
# Epoch 7/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5340 - accuracy: 0.7217
# Epoch 8/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5239 - accuracy: 0.7419
# Epoch 9/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5328 - accuracy: 0.7407
# Epoch 10/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4951 - accuracy: 0.7666
# Epoch 11/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4953 - accuracy: 0.7778
# Epoch 12/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4741 - accuracy: 0.7834
# Epoch 13/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.7969
# Epoch 14/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.8025
# Epoch 15/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.8036
# Epoch 16/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4523 - accuracy: 0.8002
# Epoch 17/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.8047
# Epoch 18/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4730 - accuracy: 0.7890
# Epoch 19/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.7969
# Epoch 20/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4466 - accuracy: 0.7991
# Epoch 21/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4597 - accuracy: 0.8025
# Epoch 22/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7991
# Epoch 23/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.8036
# Epoch 24/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4550 - accuracy: 0.7901
# Epoch 25/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.8137
# Epoch 26/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4372 - accuracy: 0.7991
# Epoch 27/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.8081
# Epoch 28/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.8114
# Epoch 29/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.8081
# Epoch 30/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.8036
# Epoch 31/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.8070
# Epoch 32/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4257 - accuracy: 0.8070
# Epoch 33/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4297 - accuracy: 0.8126
# Epoch 34/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.7991
# Epoch 35/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.8137
# Epoch 36/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4521 - accuracy: 0.8103
# Epoch 37/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4204 - accuracy: 0.8283
# Epoch 38/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.8103
# Epoch 39/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4252 - accuracy: 0.8114
# Epoch 40/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 0.8081
# Epoch 41/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4215 - accuracy: 0.8159
# Epoch 42/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.8137
# Epoch 43/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4255 - accuracy: 0.8148
# Epoch 44/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4358 - accuracy: 0.7969
# Epoch 45/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4203 - accuracy: 0.8159
# Epoch 46/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4177 - accuracy: 0.8182
# Epoch 47/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4330 - accuracy: 0.8092
# Epoch 48/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4190 - accuracy: 0.8114
# Epoch 49/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8159
# Epoch 50/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4276 - accuracy: 0.8171
# Epoch 51/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.8193
# Epoch 52/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4220 - accuracy: 0.8227
# Epoch 53/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4230 - accuracy: 0.8182
# Epoch 54/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4172 - accuracy: 0.8328
# Epoch 55/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.8092
# Epoch 56/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4159 - accuracy: 0.8260
# Epoch 57/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4213 - accuracy: 0.8047
# Epoch 58/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4135 - accuracy: 0.8215
# Epoch 59/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4182 - accuracy: 0.8193
# Epoch 60/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.8204
# Epoch 61/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4204 - accuracy: 0.8047
# Epoch 62/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4117 - accuracy: 0.8204
# Epoch 63/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4163 - accuracy: 0.8171
# Epoch 64/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4077 - accuracy: 0.8227
# Epoch 65/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4084 - accuracy: 0.8204
# Epoch 66/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4170 - accuracy: 0.8249
# Epoch 67/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.8182
# Epoch 68/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.8227
# Epoch 69/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8249
# Epoch 70/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4205 - accuracy: 0.8058
# Epoch 71/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4158 - accuracy: 0.8126
# Epoch 72/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8193
# Epoch 73/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8215
# Epoch 74/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8328
# Epoch 75/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4108 - accuracy: 0.8126
# Epoch 76/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8070
# Epoch 77/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.8171
# Epoch 78/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4062 - accuracy: 0.8159
# Epoch 79/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8227
# Epoch 80/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4005 - accuracy: 0.8081
# Epoch 81/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 0.8283
# Epoch 82/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4131 - accuracy: 0.8126
# Epoch 83/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8204
# Epoch 84/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4066 - accuracy: 0.8204
# Epoch 85/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4116 - accuracy: 0.8070
# Epoch 86/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8227
# Epoch 87/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8305
# Epoch 88/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8227
# Epoch 89/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8238
# Epoch 90/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3910 - accuracy: 0.8294
# Epoch 91/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8182
# Epoch 92/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4201 - accuracy: 0.8114
# Epoch 93/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.8126
# Epoch 94/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8316
# Epoch 95/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8272
# Epoch 96/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8294
# Epoch 97/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4025 - accuracy: 0.8215
# Epoch 98/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8204
# Epoch 99/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8238
# Epoch 100/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8260

# %%
acc = history.history['accuracy']
train_loss = history.history['loss']

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, label='Training acc')
plt.title('Training accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, train_loss, label='Training loss')
plt.title('Training loss')
plt.legend()

plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 14/14 [==============================] - 0s 1ms/step

# %%
output = np.c_[test_data["PassengerId"].to_numpy(), y_pred].astype(int)
output = pd.DataFrame(output, columns = ['PassengerId', 'Survived'])
output.to_csv("MLP_submission.csv", index = False)
